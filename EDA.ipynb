# %%
import pandas as pd

# %%
df = pd.read_csv('./dataCars.csv',index_col=False)
df
# Out:
#                                                Nombre       Type  \
# 0                             2017 Mercedes-Benz 250   Hatchback
# 1                                    2008 Suzuki Sx4   Hatchback
# 2      2018 Subaru Impreza 2.0i CVT Auto XS Sport 4WD  Hatchback
# 3                       2016 Volvo V40 1.6 D2 Comfort  Hatchback
# 4   2021 Mercedes-Benz A 45 Amg 2.0 Mercedes-AMG A...  Hatchback
# 5            2019 Peugeot 308 2.0 BlueHDI 180 Auto GT  Hatchback
# 6                   2017 Volkswagen Golf 1.6 MSI Auto  Hatchback
# 7                                 2011 Mazda 3 Sport   Hatchback
# 8                            2013 Suzuki Swift 1.4 GL  Hatchback
# 9                               2017 Kia Rio 5 LX 1.2  Hatchback
# 10          2016 Peugeot 208 1.6 HDI 92 HPActive Pack  Hatchback
# 11                            2017 Mercedes-Benz 250   Hatchback
# 12                                   2008 Suzuki Sx4   Hatchback
# ...
